# %%
import pandas as pd

# %%
listings=pd.read_csv("/kaggle/input/indias-airbnb-gems-2024-trending-picks/Airbnb_India_Top_500.csv")

# %%
listings.head()
# Out:
#                             address  isHostedBySuperhost  location/lat  \
# 0   Manali, Himachal Pradesh, India                False      32.22330
# 1   Manali, Himachal Pradesh, India                False      32.22352
# 2                        Goa, India                False      15.50400
# 3  Bhuntar, Himachal Pradesh, India                False      31.88656
# 4          Jaipur, Rajasthan, India                False      26.85991
#
#    location/lng                                              name  \
# 0      77.18228                        HighQ Manali / Deluxe Room
# 1      77.18152                      Highq manali / 3 BHK Cottage
# 2      73.86600       Best view of the river from your terrace 04
# 3      77.14467                                          Shabashe
# 4      75.66909  Luxurious Independent Studio with Wifi & Kitchen
#
#    numberOfGuests  pricing/rate/amount                    roomType  stars
# 0               3                 8946               Room in hotel    NaN
# 1               9                 9124               Room in hotel    NaN
# 2               4                 9900        Private room in home   4.00
# 3               1                 8684  Shared room in rental unit    NaN
# 4               1                20690                Entire condo   4.75

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   address              500 non-null    object
#  1   isHostedBySuperhost  500 non-null    bool
#  2   location/lat         500 non-null    float64
#  3   location/lng         500 non-null    float64
#  4   name                 500 non-null    object
#  5   numberOfGuests       500 non-null    int64
#  6   pricing/rate/amount  500 non-null    int64
#  7   roomType             500 non-null    object
#  8   stars                196 non-null    float64
# dtypes: bool(1), float64(3), int64(2), object(3)
# memory usage: 31.9+ KB

# %%
listings.isnull().sum()  #Sorting the null value
# Out:
# address                  0
# isHostedBySuperhost      0
# location/lat             0
# location/lng             0
# name                     0
# numberOfGuests           0
# pricing/rate/amount      0
# roomType                 0
# stars                  304
# dtype: int64

# %%
#Sum of guests in the room
total_guests = listings['numberOfGuests'].sum()
print("Total Number of Guests in Top 500 AirBnB are ",total_guests)
# Out:
# Total Number of Guests in Top 500 AirBnB are  5780

# %%
#to obtain total number of Address
total_address = listings['address'].nunique()
print("Total Number of address are :", total_address)
# Out:
# Total Number of address are : 217

# %%
#Address have to be splitted to Address,State and Country for better Analysis
split_address = listings['address'].str.split(', ', expand=True)
listings['Locality'] = split_address[0]
listings['State'] = split_address[1]
listings['Country'] = split_address[2]

#removal of address column
listings.drop('address', axis=1, inplace=True)

# %%
listings.head()
# Out:
#    isHostedBySuperhost  location/lat  location/lng  \
# 0                False      32.22330      77.18228
# 1                False      32.22352      77.18152
# 2                False      15.50400      73.86600
# 3                False      31.88656      77.14467
# 4                False      26.85991      75.66909
#
#                                                name  numberOfGuests  \
# 0                        HighQ Manali / Deluxe Room               3
# 1                      Highq manali / 3 BHK Cottage               9
# 2       Best view of the river from your terrace 04               4
# 3                                          Shabashe               1
# 4  Luxurious Independent Studio with Wifi & Kitchen               1
#
#    pricing/rate/amount                    roomType  stars Locality  \
# 0                 8946               Room in hotel    NaN   Manali
# 1                 9124               Room in hotel    NaN   Manali
# 2                 9900        Private room in home   4.00      Goa
# 3                 8684  Shared room in rental unit    NaN  Bhuntar
# 4                20690                Entire condo   4.75   Jaipur
#
#               State Country
# 0  Himachal Pradesh   India
# 1  Himachal Pradesh   India
# 2             India    None
# 3  Himachal Pradesh   India
# 4         Rajasthan   India

# %%
#Renaming Columns
listings.rename(columns={'isHostedBySuperhost':'Superhost','pricing/rate/amount':'price','location/lat':'Latitude','location/lng':'Longitude','name':'Name','numberOfGuests':'Guest Count','pricing/rate/amount':'Price','roomType':'Room Type','stars':'Ratings'}, inplace=True)
listings.head(0)
# Out:
# Empty DataFrame
# Columns: [Superhost, Latitude, Longitude, Name, Guest Count, Price, Room Type, Ratings, Locality, State, Country]
# Index: []

# %%
#Need to rearrage the data frame
listings=listings[['Name', 'Locality', 'State', 'Country', 'Latitude', 'Longitude', 'Room Type', 'Guest Count','Price', 'Ratings']]

# %%
listings.head()
# Out:
#                                                Name Locality  \
# 0                        HighQ Manali / Deluxe Room   Manali
# 1                      Highq manali / 3 BHK Cottage   Manali
# 2       Best view of the river from your terrace 04      Goa
# 3                                          Shabashe  Bhuntar
# 4  Luxurious Independent Studio with Wifi & Kitchen   Jaipur
#
#               State Country  Latitude  Longitude                   Room Type  \
# 0  Himachal Pradesh   India  32.22330   77.18228               Room in hotel
# 1  Himachal Pradesh   India  32.22352   77.18152               Room in hotel
# 2             India    None  15.50400   73.86600        Private room in home
# 3  Himachal Pradesh   India  31.88656   77.14467  Shared room in rental unit
# 4         Rajasthan   India  26.85991   75.66909                Entire condo
#
#    Guest Count  Price  Ratings
# 0            3   8946      NaN
# 1            9   9124      NaN
# 2            4   9900     4.00
# 3            1   8684      NaN
# 4            1  20690     4.75

# %%
#Obtaining names excluding repeated ones
norepeat_name = listings['Name'].nunique()
print("Total exclusive Names:", norepeat_name)
# Out:
# Total exclusive Names: 499

# %%
#Total Room Types
room_types = listings['Room Type'].nunique()
print("Total exclusive Room types:", room_types)
# Out:
# Total exclusive Room types: 40

# %%
#Tabulating room types
import pandas as pd
from tabulate import tabulate
roomtype_counts = listings['Room Type'].value_counts()
roomtype_counts_listings = pd.DataFrame({'Room Type': roomtype_counts.index, 'Number': roomtype_counts.values})
print(tabulate(roomtype_counts_listings, headers='keys', tablefmt='psql'))
# Out:
# +----+-----------------------------------+----------+
# |    | Room Type                         |   Number |
# |----+-----------------------------------+----------|
# |  0 | Entire villa                      |      220 |
# |  1 | Farm stay                         |       58 |
# |  2 | Entire home                       |       49 |
# |  3 | Entire bungalow                   |       29 |
# |  4 | Room in hotel                     |       19 |
# |  5 | Private room in resort            |       13 |
# |  6 | Room in boutique hotel            |       12 |
# |  7 | Private room in villa             |       11 |
# |  8 | Private room in bed and breakfast |        9 |
# |  9 | Entire condo                      |        8 |
# | 10 | Entire cottage                    |        7 |
# | 11 | Entire rental unit                |        7 |
# | 12 | Houseboat                         |        6 |
# | 13 | Entire chalet                     |        5 |
# | 14 | Entire serviced apartment         |        4 |
# | 15 | Room in heritage hotel            |        4 |
# | 16 | Room in serviced apartment        |        3 |
# | 17 | Private room in bungalow          |        3 |
# | 18 | Entire place                      |        3 |
# | 19 | Boat                              |        3 |
# | 20 | Room in resort                    |        2 |
# | 21 | Entire vacation home              |        2 |
# | 22 | Private room in castle            |        2 |
# | 23 | Private room in cottage           |        2 |
# | 24 | Private room in nature lodge      |        2 |
# | 25 | Private room in home              |        2 |
# | 26 | Castle                            |        2 |
# | 27 | Treehouse                         |        1 |
# | 28 | Shared room in rental unit        |        1 |
# | 29 | Campsite                          |        1 |
# | 30 | Entire home/apt                   |        1 |
# | 31 | Private room in chalet            |        1 |
# | 32 | Private room in condo             |        1 |
# | 33 | Camper/RV                         |        1 |
# | 34 | Private room in earthen home      |        1 |
# | 35 | Hut                               |        1 |
# | 36 | Tent                              |        1 |
# | 37 | Private room in farm stay         |        1 |
# | 38 | Shared room in guest suite        |        1 |
# | 39 | Entire cabin                      |        1 |
# +----+-----------------------------------+----------+

# %%
#Total Number of stays per city
import pandas as pd
from tabulate import tabulate
citywise_counts = listings['Locality'].value_counts()
citywise_counts_listings = pd.DataFrame({'Locality': citywise_counts.index,'Count': citywise_counts.values})
print(tabulate(citywise_counts_listings, headers='keys', tablefmt='psql'))
# Out:
# +-----+----------------------+---------+
# |     | Locality             |   Count |
# |-----+----------------------+---------|
# |   0 | Candolim             |      25 |
# |   1 | New Delhi            |      22 |
# |   2 | Lonavla              |      16 |
# |   3 | Anjuna               |      15 |
# |   4 | Jaipur               |      14 |
# |   5 | Calangute            |      14 |
# |   6 | Lonavala             |      13 |
# |   7 | Gurugram             |      11 |
# |   8 | Udaipur              |      11 |
# |   9 | Goa                  |      10 |
# |  10 | Assagao              |       9 |
# |  11 | Vagator              |       9 |
# |  12 | Manali               |       8 |
# |  13 | Mumbai               |       8 |
# |  14 | North Goa            |       8 |
# |  15 | Alappuzha            |       8 |
# |  16 | Chennai              |       7 |
# |  17 | Alibag               |       7 |
# |  18 | Sangolda             |       6 |
# |  19 | Baga                 |       6 |
# |  20 | Nerul                |       6 |
# |  21 | Dehradun             |       5 |
# |  22 | Nainital             |       5 |
# |  23 | Panchgani            |       5 |
# |  24 | Bengaluru            |       5 |
# |  25 | Mandrem              |       5 |
# |  26 | Arpora               |       5 |
# |  27 | Mahabaleshwar        |       4 |
# |  28 | Kasauli              |       4 |
# |  29 | Kodaikanal           |       4 |
# |  30 | Kochi                |       4 |
# |  31 | Rishikesh            |       4 |
# |  32 | Vijayawada           |       3 |
# |  33 | Bhuntar              |       3 |
# |  34 | Nashik               |       3 |
# |  35 | Penha de França      |       3 |
# |  36 | Zirad                |       3 |
# |  37 | Kumarakom            |       3 |
# |  38 | Parra                |       3 |
# |  39 | Reis Magos           |       3 |
# |  40 | Kune N.m.            |       3 |
# |  41 | Mararikulam          |       2 |
# |  42 | Dona Paula           |       2 |
# |  43 | Awas                 |       2 |
# |  44 | Moira                |       2 |
# |  45 | Kihim                |       2 |
# |  46 | Gurgaon              |       2 |
# |  47 | Ahmedabad            |       2 |
# |  48 | Maravanthe           |       2 |
# |  49 | Ramgarh              |       2 |
# |  50 | Varanasi             |       2 |
# |  51 | Igatpuri             |       2 |
# |  52 | Krishnagiri          |       2 |
# |  53 | Mussoorie            |       2 |
# |  54 | Pune                 |       2 |
# |  55 | Verla                |       2 |
# |  56 | Khandala             |       2 |
# |  57 | Karjat               |       2 |
# |  58 | Saligao              |       2 |
# |  59 | Panaji               |       2 |
# |  60 | Puducherry           |       2 |
# |  61 | Kotagiri             |       2 |
# |  62 | Pawnanagar           |       2 |
# |  63 | Colovale             |       2 |
# |  64 | Barashiv             |       2 |
# |  65 | Canacona             |       2 |
# |  66 | Sadahalli            |       1 |
# |  67 | Sheel                |       1 |
# |  68 | Shashbani            |       1 |
# |  69 | Mirik                |       1 |
# |  70 | Vashist              |       1 |
# |  71 | Indore               |       1 |
# |  72 | Khingar              |       1 |
# |  73 | Hosur                |       1 |
# |  74 | Ramnagar             |       1 |
# |  75 | Palampur             |       1 |
# |  76 | Dodamarg Maharashtra |       1 |
# |  77 | Anjuna - Vagator     |       1 |
# |  78 | Kothali              |       1 |
# |  79 | Amritsar             |       1 |
# |  80 | Haleyangadi          |       1 |
# |  81 | Pawna                |       1 |
# |  82 | Bhimtal              |       1 |
# |  83 | Bangalore Urban      |       1 |
# |  84 | Navelim              |       1 |
# |  85 | Bani Park            |       1 |
# |  86 | Kanthavli            |       1 |
# |  87 | Ashvem Beach         |       1 |
# |  88 | Agra                 |       1 |
# |  89 | Puthenvelikara       |       1 |
# |  90 | Mount Abu            |       1 |
# |  91 | Karjat.              |       1 |
# |  92 | Hairiya Gaon         |       1 |
# |  93 | Chaukariya           |       1 |
# |  94 | Nawanpind Sardaran   |       1 |
# |  95 | Nedumudy             |       1 |
# |  96 | Udupi                |       1 |
# |  97 | Marsur               |       1 |
# |  98 | Siolim               |       1 |
# |  99 | Varca                |       1 |
# | 100 | Pravithanam          |       1 |
# | 101 | Chapora              |       1 |
# | 102 | Lanja                |       1 |
# | 103 | Ranga Reddy          |       1 |
# | 104 | Colva                |       1 |
# | 105 | Alto Porvorim        |       1 |
# | 106 | Dhanolti             |       1 |
# | 107 | Nalambi              |       1 |
# | 108 | Sughandhagiry        |       1 |
# | 109 | Chalnichhina         |       1 |
# | 110 | Mukhteshwar          |       1 |
# | 111 | Jojawar              |       1 |
# | 112 | Bini                 |       1 |
# | 113 | Kutta                |       1 |
# | 114 | Ooty                 |       1 |
# | 115 | Bagalur              |       1 |
# | 116 | Lucknow              |       1 |
# | 117 | Marudanapalli        |       1 |
# | 118 | Uttarakhand          |       1 |
# | 119 | Kanathur             |       1 |
# | 120 | Morve                |       1 |
# | 121 | Chikkamagaluru       |       1 |
# | 122 | Haripur              |       1 |
# | 123 | Diveagar             |       1 |
# | 124 | Bhilar               |       1 |
# | 125 | Wavarle              |       1 |
# | 126 | Thattekad            |       1 |
# | 127 | Kanatal              |       1 |
# | 128 | Gokarna              |       1 |
# | 129 | Satirje              |       1 |
# | 130 | Haryana              |       1 |
# | 131 | Waghodia             |       1 |
# | 132 | Aryad South          |       1 |
# | 133 | Nandgaon             |       1 |
# | 134 | Delhi                |       1 |
# | 135 | Amritsar Cantt.      |       1 |
# | 136 | Calangute Beach      |       1 |
# | 137 | Nilgiris             |       1 |
# | 138 | Ashapura             |       1 |
# | 139 | Mahagaon             |       1 |
# | 140 | Kalwar               |       1 |
# | 141 | India                |       1 |
# | 142 | Alibaug              |       1 |
# | 143 | Janedghat            |       1 |
# | 144 | Bujra                |       1 |
# | 145 | Kolkata              |       1 |
# | 146 | Kasol                |       1 |
# | 147 | Patna                |       1 |
# | 148 | Khoohdi              |       1 |
# | 149 | Ambelim              |       1 |
# | 150 | Kukas                |       1 |
# | 151 | Dona Paula Beach     |       1 |
# | 152 | Panjim               |       1 |
# | 153 | Ganaheda             |       1 |
# | 154 | Banjar               |       1 |
# | 155 | Morjim               |       1 |
# | 156 | Aru                  |       1 |
# | 157 | Pathau               |       1 |
# | 158 | Nathuwakhan          |       1 |
# | 159 | Loutolim             |       1 |
# | 160 | Panna                |       1 |
# | 161 | Kullu                |       1 |
# | 162 | SALIGAO              |       1 |
# | 163 | Ribandar             |       1 |
# | 164 | Guirim               |       1 |
# | 165 | Assonora             |       1 |
# | 166 | Gauravaddo           |       1 |
# | 167 | Abu Road             |       1 |
# | 168 | Govind Nagar         |       1 |
# | 169 | Marna                |       1 |
# | 170 | Brittona             |       1 |
# | 171 | Arambol              |       1 |
# | 172 | Aundholi             |       1 |
# | 173 | Bagru                |       1 |
# | 174 | Narendra Nagar       |       1 |
# | 175 | Assagaon             |       1 |
# | 176 | Dabolim              |       1 |
# | 177 | Tangmarg             |       1 |
# | 178 | Tilase               |       1 |
# | 179 | Virajpet             |       1 |
# | 180 | Ernakulam            |       1 |
# | 181 | Bardez               |       1 |
# | 182 | BARDEZ               |       1 |
# | 183 | Aldona               |       1 |
# | 184 | Garat Pur Bas        |       1 |
# | 185 | Vadanemmeli          |       1 |
# | 186 | Nerul                |       1 |
# | 187 | Shahpur              |       1 |
# | 188 | Chouk                |       1 |
# | 189 | Raigad               |       1 |
# | 190 | Chuchot Yakma        |       1 |
# | 191 | Bhandar Gaon         |       1 |
# | 192 | Candolim             |       1 |
# | 193 | Achrol               |       1 |
# | 194 | Pawas                |       1 |
# | 195 | Bijainagar           |       1 |
# | 196 | Aamwala              |       1 |
# | 197 | Kashid               |       1 |
# | 198 | Kamshet              |       1 |
# | 199 | Gadherni             |       1 |
# | 200 | Kumdal               |       1 |
# | 201 | Kerala               |       1 |
# | 202 | Almora               |       1 |
# | 203 | Coimbatore           |       1 |
# | 204 | Raiseena             |       1 |
# | 205 | Munnar               |       1 |
# +-----+----------------------+---------+

# %%
#Total Number of stays per state
import pandas as pd
from tabulate import tabulate
statewise_counts = listings['State'].value_counts()
statewise_counts_listings = pd.DataFrame({'State': statewise_counts.index,'Count': statewise_counts.values})
print(tabulate(statewise_counts_listings, headers='keys', tablefmt='psql'))
# Out:
# +----+-----------------------------+---------+
# |    | State                       |   Count |
# |----+-----------------------------+---------|
# |  0 | Goa                         |     151 |
# |  1 | Maharashtra                 |      95 |
# |  2 | Rajasthan                   |      38 |
# |  3 | Uttarakhand                 |      32 |
# |  4 | Himachal Pradesh            |      24 |
# |  5 | Kerala                      |      24 |
# |  6 | Delhi                       |      22 |
# |  7 | India                       |      22 |
# |  8 | Tamil Nadu                  |      20 |
# |  9 | Haryana                     |      14 |
# | 10 | Karnataka                   |      13 |
# | 11 | Uttar Pradesh               |       4 |
# | 12 | Andhra Pradesh              |       3 |
# | 13 | Punjab                      |       3 |
# | 14 | Gujarat                     |       3 |
# | 15 | MH                          |       3 |
# | 16 | GA                          |       2 |
# | 17 | North Goa                   |       2 |
# | 18 | TN                          |       2 |
# | 19 | West Bengal                 |       2 |
# | 20 | Madhya Pradesh              |       2 |
# | 21 | कर्नाटक                       |       1 |
# | 22 | goa                         |       1 |
# | 23 | KA                          |       1 |
# | 24 | Telangana                   |       1 |
# | 25 | Karle                       |       1 |
# | 26 | Uttrakhand                  |       1 |
# | 27 | Bardez                      |       1 |
# | 28 | महाराष्ट्र                      |       1 |
# | 29 | Andaman and Nicobar Islands |       1 |
# | 30 | Chennai                     |       1 |
# | 31 | Bardez North Goa            |       1 |
# | 32 | HR                          |       1 |
# | 33 | Kodagu                      |       1 |
# | 34 | Jammu and Kashmir           |       1 |
# | 35 | Bihar                       |       1 |
# | 36 | Nasirabad                   |       1 |
# | 37 | Calangute                   |       1 |
# | 38 | HP                          |       1 |
# +----+-----------------------------+---------+

# %% [raw]
# #Requires data cleansing and transformation as there are many Hindi Names as well as repeated names(Goa,GA etc) based on primary analysis of the table

# %%
listings['State'] = listings['State'].replace(['Chennai','TN'], 'Tamil Nadu')
listings['State'] = listings['State'].replace(['Kodagu','Karle','KA','कर्नाटक'], 'Karnataka')
listings['State'] =listings['State'].replace(['goa','GA','Bardez','Bardez North Goa','North Goa','Calangute'], 'Goa')
listings['State'] =listings['State'].replace(['महाराष्ट्र','MH'], 'Maharashtra')
listings['State'] = listings['State'].replace({'HP': 'Himachal Pradesh','HR':'Haryana', 'Uttrakhand':'Uttarakhand','Nasirabad': 'Rajasthan'})

# %%
#Let us formulate the table again
import pandas as pd
from tabulate import tabulate
statewise_counts = listings['State'].value_counts()
statewise_counts_listings = pd.DataFrame({'State': statewise_counts.index,'Count': statewise_counts.values})
print(tabulate(statewise_counts_listings, headers='keys', tablefmt='psql'))
# Out:
# +----+-----------------------------+---------+
# |    | State                       |   Count |
# |----+-----------------------------+---------|
# |  0 | Goa                         |     159 |
# |  1 | Maharashtra                 |      99 |
# |  2 | Rajasthan                   |      38 |
# |  3 | Uttarakhand                 |      33 |
# |  4 | Himachal Pradesh            |      25 |
# |  5 | Kerala                      |      24 |
# |  6 | Tamil Nadu                  |      23 |
# |  7 | Delhi                       |      22 |
# |  8 | India                       |      22 |
# |  9 | Karnataka                   |      17 |
# | 10 | Haryana                     |      15 |
# | 11 | Uttar Pradesh               |       4 |
# | 12 | Gujarat                     |       3 |
# | 13 | Punjab                      |       3 |
# | 14 | Andhra Pradesh              |       3 |
# | 15 | West Bengal                 |       2 |
# | 16 | Madhya Pradesh              |       2 |
# | 17 | Nasirabad                   |       1 |
# | 18 | Bihar                       |       1 |
# | 19 | Andaman and Nicobar Islands |       1 |
# | 20 | Jammu and Kashmir           |       1 |
# | 21 | Telangana                   |       1 |
# +----+-----------------------------+---------+

# %%
#Need to resolve the issue of Nasirabad on the above table

# %%
listings['State'] = listings['State'].replace({'Nasirabad ': 'Rajasthan'})

# %%
#Let us formulate the table again
import pandas as pd
from tabulate import tabulate
statewise_counts = listings['State'].value_counts()
statewise_counts_listings = pd.DataFrame({'State': statewise_counts.index,'Count': statewise_counts.values})
print(tabulate(statewise_counts_listings, headers='keys', tablefmt='psql'))

#there is a blank space after Nasirabad in the data
# Out:
# +----+-----------------------------+---------+
# |    | State                       |   Count |
# |----+-----------------------------+---------|
# |  0 | Goa                         |     159 |
# |  1 | Maharashtra                 |      99 |
# |  2 | Rajasthan                   |      39 |
# |  3 | Uttarakhand                 |      33 |
# |  4 | Himachal Pradesh            |      25 |
# |  5 | Kerala                      |      24 |
# |  6 | Tamil Nadu                  |      23 |
# |  7 | Delhi                       |      22 |
# |  8 | India                       |      22 |
# |  9 | Karnataka                   |      17 |
# | 10 | Haryana                     |      15 |
# | 11 | Uttar Pradesh               |       4 |
# | 12 | Punjab                      |       3 |
# | 13 | Andhra Pradesh              |       3 |
# | 14 | Gujarat                     |       3 |
# | 15 | Madhya Pradesh              |       2 |
# | 16 | West Bengal                 |       2 |
# | 17 | Andaman and Nicobar Islands |       1 |
# | 18 | Bihar                       |       1 |
# | 19 | Jammu and Kashmir           |       1 |
# | 20 | Telangana                   |       1 |
# +----+-----------------------------+---------+

# %%
#There is India in the above state list which needs to be filtered out.We need to segregate such rows from the table and analyse the data for any leads
from tabulate import tabulate
indiarow = listings[listings['State'] == 'India']
segr_row = indiarow.values.tolist()
print(tabulate(segr_row, headers=listings.columns))
# Out:
# Name                                                Locality              State    Country      Latitude    Longitude  Room Type                            Guest Count    Price    Ratings
# --------------------------------------------------  --------------------  -------  ---------  ----------  -----------  ---------------------------------  -------------  -------  ---------
# Best view of the river from your terrace 04         Goa                   India                 15.504        73.866   Private room in home                           4     9900       4
# Pahalgham Cottage Next to the River                 Aru                   India                 34.0909       75.2641  Entire cottage                                10      782     nan
# Escape to Paradise, Your Group Getaway 12-36 Pax    Goa                   India                 15.535        73.767   Entire villa                                  16      978       5
# Private Room  For LONG STAY  with attached bath,    Delhi                 India                 28.6694       77.2037  Private room in bed and breakfast              2     1924     nan
# Luxury Boutique Hotel.                              Goa                   India                 15.3155       73.913   Room in boutique hotel                        16      880       4.94
# Cherry Flower.                                      Mahagaon              India                 18.697        73.506   Entire bungalow                               16     1546       4.53
# Villa Helena Heritage Guest House - Full Villa      Puducherry            India                 11.928        79.833   Private room in bed and breakfast             16      589     nan
# Spice Routes Houseboat- Saffron                     Alappuzha             India                  9.46065      76.3945  Houseboat                                      2      541     nan
# chomal huts                                         Chuchot Yakma         India                 34.0869       77.5807  Private room in resort                        10      541     nan
# Family superior cottage - Morning glory             Kerala                India                 11.5305       76.155   Private room in bed and breakfast              4      722     nan
# 4bhk Sea View Villa @reismagos Candolim             Goa                   India                 15.4995       73.7951  Entire home                                   12      457     nan
# Jain Farms                                          Haryana               India                 28.3724       77.0529  Farm stay                                     16      447     nan
# 4BR Casa Do Amor Pvt Pool & Breakfast               Goa                   India                 15.5421       73.8111  Entire villa                                  11      480     nan
# Shivaaz Holiday Farms - Near Mopa Airport Goa       Dodamarg Maharashtra  India                 15.6811       74.0541  Farm stay                                     16      463     nan
# Mingle with the Stars in an Open to Sky Bathroom    Goa                   India                 15.535        73.767   Entire home                                   16      425       4.92
# Private Luxury Home With Spacious Design            Goa                   India                 15.535        73.767   Entire home                                   14      473     nan
# Aashraya on the Ganga : Himalayan Farmstay Retreat  Uttarakhand           India                 30.064        78.5186  Farm stay                                     12      412       4.5
# Luxury Villa with Private Pool                      Puducherry            India                 11.918        79.82    Entire home                                   15      481     nan
# 3- bedroom Villa with pvt  swimming pool            Goa                   India                 15.5267       73.7614  Private room in resort                         6      439     nan
# A Cosy Villa near the beach in Goa                  Varca                 India                 15.2228       73.9369  Entire villa                                  10      134       4.6
# 3 Bhk Luxury Beach Villa.                           Goa                   India                 15.5144       73.7662  Entire bungalow                               10      139       4.92
# HAPPY 2 U
# Candolim.
# Vagator ,Cosy & Modern 3 bedroom villa for 8        Goa                   India                 15.5987       73.757   Entire villa                                   8      196       5

# %%
#Locality got misplaced with the state name and state name got misplaced with country name

# %%
listings.loc[listings['State'] == 'India', 'State'] = listings.loc[listings['State'] == 'India', 'Locality']

# %%
#Let us formulate the table again
import pandas as pd
from tabulate import tabulate
statewise_counts = listings['State'].value_counts()
statewise_counts_listings = pd.DataFrame({'State': statewise_counts.index,'Count': statewise_counts.values})
print(tabulate(statewise_counts_listings, headers='keys', tablefmt='psql'))
# Out:
# +----+-----------------------------+---------+
# |    | State                       |   Count |
# |----+-----------------------------+---------|
# |  0 | Goa                         |     169 |
# |  1 | Maharashtra                 |      99 |
# |  2 | Rajasthan                   |      39 |
# |  3 | Uttarakhand                 |      34 |
# |  4 | Himachal Pradesh            |      25 |
# |  5 | Kerala                      |      25 |
# |  6 | Delhi                       |      23 |
# |  7 | Tamil Nadu                  |      23 |
# |  8 | Karnataka                   |      17 |
# |  9 | Haryana                     |      16 |
# | 10 | Uttar Pradesh               |       4 |
# | 11 | Punjab                      |       3 |
# | 12 | Andhra Pradesh              |       3 |
# | 13 | Gujarat                     |       3 |
# | 14 | Madhya Pradesh              |       2 |
# | 15 | West Bengal                 |       2 |
# | 16 | Puducherry                  |       2 |
# | 17 | Aru                         |       1 |
# | 18 | Varca                       |       1 |
# | 19 | Dodamarg Maharashtra        |       1 |
# | 20 | Jammu and Kashmir           |       1 |
# | 21 | Andaman and Nicobar Islands |       1 |
# | 22 | Chuchot Yakma               |       1 |
# | 23 | Alappuzha                   |       1 |
# | 24 | Bihar                       |       1 |
# | 25 | Mahagaon                    |       1 |
# | 26 | Telangana                   |       1 |
# +----+-----------------------------+---------+

# %%
#There needs to be more data cleansing after exclusion of India

# %%
listings['State'] =listings['State'].replace(['Dodamarg Maharashtra','Mahagaon'], 'Maharashtra')
listings['State'] = listings['State'].replace({'Alappuzha': 'Kerala','Chuchot Yakma':'Ladakh','Nasirabad': 'Rajasthan','Varca':'Goa','Aru':'Jammu and Kashmir'})

# %%
#Let us formulate the table again after replacing Alapuzha,Varca,Aru etc
import pandas as pd
from tabulate import tabulate
statewise_counts = listings['State'].value_counts()
statewise_counts_listings = pd.DataFrame({'State': statewise_counts.index,'Count': statewise_counts.values})
print(tabulate(statewise_counts_listings, headers='keys', tablefmt='psql'))
# Out:
# +----+-----------------------------+---------+
# |    | State                       |   Count |
# |----+-----------------------------+---------|
# |  0 | Goa                         |     170 |
# |  1 | Maharashtra                 |     101 |
# |  2 | Rajasthan                   |      39 |
# |  3 | Uttarakhand                 |      34 |
# |  4 | Kerala                      |      26 |
# |  5 | Himachal Pradesh            |      25 |
# |  6 | Tamil Nadu                  |      23 |
# |  7 | Delhi                       |      23 |
# |  8 | Karnataka                   |      17 |
# |  9 | Haryana                     |      16 |
# | 10 | Uttar Pradesh               |       4 |
# | 11 | Gujarat                     |       3 |
# | 12 | Punjab                      |       3 |
# | 13 | Andhra Pradesh              |       3 |
# | 14 | West Bengal                 |       2 |
# | 15 | Puducherry                  |       2 |
# | 16 | Madhya Pradesh              |       2 |
# | 17 | Jammu and Kashmir           |       2 |
# | 18 | Bihar                       |       1 |
# | 19 | Andaman and Nicobar Islands |       1 |
# | 20 | Ladakh                      |       1 |
# | 21 | Telangana                   |       1 |
# +----+-----------------------------+---------+

# %%
#Listing out null value rows
null_rows = listings[listings['Country'].isna() | listings['Country'].eq('')]

# %%
null_state=listings[listings['State'].isna() | listings['State'].eq('')]

# %%
listings.fillna({'stars':'0'}, inplace=True)

# %%
listings.loc[listings['Country'].isna(), 'Country'] = 'India'

# %%
listings.fillna({'stars':'0'}, inplace=True)

# %%
listings.isnull().sum()  #Sorting the null value
# Out:
# Name             0
# Locality         0
# State            1
# Country          0
# Latitude         0
# Longitude        0
# Room Type        0
# Guest Count      0
# Price            0
# Ratings        304
# dtype: int64

# %%
listings.head()
# Out:
#                                                Name Locality  \
# 0                        HighQ Manali / Deluxe Room   Manali
# 1                      Highq manali / 3 BHK Cottage   Manali
# 2       Best view of the river from your terrace 04      Goa
# 3                                          Shabashe  Bhuntar
# 4  Luxurious Independent Studio with Wifi & Kitchen   Jaipur
#
#               State Country  Latitude  Longitude                   Room Type  \
# 0  Himachal Pradesh   India  32.22330   77.18228               Room in hotel
# 1  Himachal Pradesh   India  32.22352   77.18152               Room in hotel
# 2               Goa   India  15.50400   73.86600        Private room in home
# 3  Himachal Pradesh   India  31.88656   77.14467  Shared room in rental unit
# 4         Rajasthan   India  26.85991   75.66909                Entire condo
#
#    Guest Count  Price  Ratings
# 0            3   8946      NaN
# 1            9   9124      NaN
# 2            4   9900     4.00
# 3            1   8684      NaN
# 4            1  20690     4.75

# %%
listings.head() #rectified
# Out:
#                                                Name Locality  \
# 0                        HighQ Manali / Deluxe Room   Manali
# 1                      Highq manali / 3 BHK Cottage   Manali
# 2       Best view of the river from your terrace 04      Goa
# 3                                          Shabashe  Bhuntar
# 4  Luxurious Independent Studio with Wifi & Kitchen   Jaipur
#
#               State Country  Latitude  Longitude                   Room Type  \
# 0  Himachal Pradesh   India  32.22330   77.18228               Room in hotel
# 1  Himachal Pradesh   India  32.22352   77.18152               Room in hotel
# 2               Goa   India  15.50400   73.86600        Private room in home
# 3  Himachal Pradesh   India  31.88656   77.14467  Shared room in rental unit
# 4         Rajasthan   India  26.85991   75.66909                Entire condo
#
#    Guest Count  Price  Ratings
# 0            3   8946      NaN
# 1            9   9124      NaN
# 2            4   9900     4.00
# 3            1   8684      NaN
# 4            1  20690     4.75

# %%
listings.isnull().sum()  #Sorting the null value
# Out:
# Name             0
# Locality         0
# State            1
# Country          0
# Latitude         0
# Longitude        0
# Room Type        0
# Guest Count      0
# Price            0
# Ratings        304
# dtype: int64

# %%
null_state=listings[listings['State'].isna() | listings['State'].eq('')]

# %%
null_state
# Out:
#                                                   Name Locality State Country  \
# 101  Eternia Villa | Exclusive Pool | Modernised | ...    India  None   India
#
#      Latitude  Longitude     Room Type  Guest Count  Price  Ratings
# 101  15.50182   73.81186  Entire villa           14   3007      NaN

# %%
#based on google search it is located in locality of Reis Magos in state of Goa

# %%
listings.fillna({'State':'Goa'}, inplace=True)

# %%
listings.loc[listings['Locality'] == 'India', 'Locality'] = 'Goa'

# %%
null_state
# Out:
#                                                   Name Locality State Country  \
# 101  Eternia Villa | Exclusive Pool | Modernised | ...    India  None   India
#
#      Latitude  Longitude     Room Type  Guest Count  Price  Ratings
# 101  15.50182   73.81186  Entire villa           14   3007      NaN

# %%
listings.isnull().sum()  #Sorting the null value
# Out:
# Name             0
# Locality         0
# State            0
# Country          0
# Latitude         0
# Longitude        0
# Room Type        0
# Guest Count      0
# Price            0
# Ratings        304
# dtype: int64

# %%
#null value is completely removed from the data frame

# %%
#CLEANSED DATA
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
#downloading final data
listings.to_csv('final_data.csv', index=False)

from IPython.display import FileLink
FileLink('final_data.csv')
# Out:
# /kaggle/working/final_data.csv

# %%
#DATA ANALYSIS USING PYTHON

# %%
#PLOTTING NUMBER OF GUESTS VS PRICE
plt.figure(figsize=(10, 6))
plt.scatter(listings['Guest Count'], listings['Price'], alpha=0.5)
plt.title('Guest Count vs. Price')
plt.xlabel('Guest Count')
plt.ylabel('Price')
plt.show()

# %%
#State wise Analysis

# %%
statewise_counts
# Out:
# State
# Goa                            170
# Maharashtra                    101
# Rajasthan                       39
# Uttarakhand                     34
# Kerala                          26
# Himachal Pradesh                25
# Tamil Nadu                      23
# Delhi                           23
# Karnataka                       17
# Haryana                         16
# Uttar Pradesh                    4
# Gujarat                          3
# Punjab                           3
# Andhra Pradesh                   3
# West Bengal                      2
# Puducherry                       2
# Madhya Pradesh                   2
# Jammu and Kashmir                2
# Bihar                            1
# Andaman and Nicobar Islands      1
# Ladakh                           1
# Telangana                        1
# Name: count, dtype: int64

# %%
state_graph= pd.DataFrame({'states': statewise_counts.index, 'counts': statewise_counts.values})
states = list(state_graph['states'])
counts = list(state_graph['counts'])

# %%
colors = ['blue', 'green', 'red', 'purple', 'orange', 'yellow', 'cyan', 'magenta', 'pink', 'brown']
plt.figure(figsize=(10, 6))
bars=plt.bar(states, counts,color=colors)
plt.title('Number of Airbnb stays in each state')
plt.xlabel('States')
plt.ylabel('Airbnb stays')
plt.xticks(rotation=90)
for bar, count in zip(bars, counts):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), count,
             ha='center', va='bottom')
plt.show()

# %%
listings['Ratings'] = pd.to_numeric(listings['Ratings'], errors='coerce')
avg_rating_state = listings[listings['Ratings'] != 0].groupby('State')['Ratings'].mean()

# %%
avg_rating_state
# Out:
# State
# Andaman and Nicobar Islands         NaN
# Andhra Pradesh                      NaN
# Bihar                               NaN
# Delhi                          4.760000
# Goa                            4.668736
# Gujarat                        4.620000
# Haryana                        4.565000
# Himachal Pradesh               4.796000
# Jammu and Kashmir                   NaN
# Karnataka                      4.587143
# Kerala                         4.717143
# Ladakh                              NaN
# Madhya Pradesh                      NaN
# Maharashtra                    4.588158
# Puducherry                          NaN
# Punjab                         4.500000
# Rajasthan                      4.578000
# Tamil Nadu                     4.762727
# Telangana                      5.000000
# Uttar Pradesh                  4.785000
# Uttarakhand                    4.660909
# West Bengal                    4.435000
# Name: Ratings, dtype: float64

# %%
avg_rating_state.plot(kind='bar', figsize=(6, 4))
plt.xlabel('Average Ratings')
plt.ylabel('State')
plt.title('State-wise Average Rating (Non-zero values)')
plt.show()

# %%
filtered_listing = listings.groupby('State').filter(lambda x: x['Price'].count() >= 4)
pricing_state = filtered_listing.groupby('State')['Price'].mean()
pricing_state
# Out:
# State
# Delhi               1374.565217
# Goa                  715.181287
# Haryana              653.062500
# Himachal Pradesh    2277.840000
# Karnataka            677.176471
# Kerala               539.538462
# Maharashtra          634.950495
# Rajasthan           1238.461538
# Tamil Nadu           487.478261
# Uttar Pradesh        485.000000
# Uttarakhand          812.235294
# Name: Price, dtype: float64

# %%
pricing_state.plot(kind='bar', figsize=(6, 4))

plt.xlabel('Average Price')
plt.ylabel('State')
plt.title('State-wise Average Price')
plt.show()

# %%
import folium
from folium.plugins import HeatMap
map_india = folium.Map(location=[20.5937, 78.9629], zoom_start=5, scrollWheelZoom=False)
heat_data = listings[['Latitude', 'Longitude', 'Price']].values.tolist()
HeatMap(heat_data, radius=10).add_to(map_india)
map_india.fit_bounds([[6.5, 68.1], [35.7, 97.4]])

map_india
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3825d4a94c5454a19f5ee42e725360e9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3825d4a94c5454a19f5ee42e725360e9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3825d4a94c5454a19f5ee42e725360e9 = L.map(
#                 &quot;map_3825d4a94c5454a19f5ee42e725360e9&quot;,
#                 {
#                     center: [20.5937, 78.9629],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     scrollWheelZoom: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3a94665cd3ce4f210a9b41aec6d04abd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_3a94665cd3ce4f210a9b41aec6d04abd.addTo(map_3825d4a94c5454a19f5ee42e725360e9);
#
#
#             var heat_map_ae5a90972a64481c153b5f0d4e313c48 = L.heatLayer(
#                 [[32.2233, 77.18228, 8946.0], [32.22352, 77.18152, 9124.0], [15.504, 73.866, 9900.0], [31.88656, 77.14467, 8684.0], [26.85991, 75.66909, 20690.0], [32.01248, 77.29114, 4274.0], [32.01204, 77.2909, 4274.0], [28.36673, 77.00647, 1734.0], [26.49372, 74.5383, 1804.0], [31.63839, 77.34503, 2822.0], [15.62707, 73.7327, 902.0], [28.35517, 77.00426, 1443.0], [18.76514, 72.87878, 912.0], [13.12752, 77.56391, 882.0], [15.54799, 73.81177, 1374.0], [30.13704, 78.30683, 788.0], [15.57329, 73.7767, 978.0], [28.496, 77.166, 962.0], [34.09091, 75.26407, 782.0], [15.56203, 73.78613, 854.0], [9.58429, 76.3051, 1443.0], [18.76034, 72.88551, 1325.0], [14.9939, 74.0571, 1220.0], [29.38514, 79.45673, 842.0], [30.1373, 78.30656, 913.0], [15.58917, 73.75996, 1185.0], [29.47118, 79.58584, 1118.0], [32.29923, 77.17704, 962.0], [15.33419, 73.97759, 902.0], [15.51782, 73.76411, 782.0], [18.91863, 73.33386, 962.0], [15.59765, 73.77297, 842.0], [24.71172, 80.17358, 1443.0], [20.07376, 73.64485, 1082.0], [18.92245, 72.83399, 1503.0], [32.03766, 77.14406, 1203.0], [18.70197, 73.45109, 1004.0], [18.77152, 73.37963, 902.0], [15.50637, 73.79914, 1203.0], [15.5554, 73.78126, 782.0], [15.504, 73.866, 1203.0], [15.54944, 73.7637, 1385.0], [15.54762, 73.76425, 1529.0], [15.56865, 73.8132, 902.0], [28.443, 77.167, 1503.0], [24.49092, 73.58379, 1263.0], [15.504, 73.866, 1097.0], [28.495, 77.136, 1203.0], [15.535, 73.767, 1172.0], [9.58518, 76.42182, 788.0], [15.57058, 73.7415, 902.0], [28.49204, 77.13633, 962.0], [15.49643, 73.81885, 1168.0], [15.54723, 73.76524, 842.0], [15.62133, 73.89804, 1022.0], [28.43832, 77.18967, 1203.0], [15.535, 73.767, 888.0], [28.36638, 77.00665, 1311.0], [28.44808, 77.18313, 1203.0], [15.55636, 73.78057, 842.0], [15.535, 73.767, 978.0], [24.53351, 72.79282, 1082.0], [15.49783, 73.83033, 842.0], [15.64852, 73.81753, 962.0], [27.08777, 75.88661, 842.0], [18.77551, 73.4101, 902.0], [15.51716, 73.76421, 1153.0], [18.48283, 72.90424, 1203.0], [15.52253, 73.76319, 1143.0], [15.5164, 73.76705, 798.0], [17.92426, 73.73543, 784.0], [15.17409, 73.97429, 902.0], [30.12978, 78.3307, 1503.0], [28.66944, 77.20366, 1924.0], [31.6253, 74.8819, 36079.0], [18.70196, 73.45204, 1481.0], [15.5351, 73.75755, 897.0], [16.47665, 80.70571, 3041.0], [15.60049, 73.83723, 962.0], [15.54855, 73.75427, 782.0], [16.47685, 80.70631, 3033.0], [15.31553, 73.91299, 880.0], [12.94891, 80.26171, 893.0], [15.54477, 73.80395, 1563.0], [18.76805, 73.41268, 1203.0], [15.537, 73.768, 3007.0], [30.31502, 78.03482, 1581.0], [30.31512, 78.03483, 1756.0], [16.47528, 80.70549, 3041.0], [15.60224, 73.78022, 998.0], [11.33, 76.803, 993.0], [15.59941, 73.7575, 940.0], [15.66367, 73.71241, 902.0], [18.92181, 72.83607, 1924.0], [18.64594, 72.89102, 1804.0], [32.2409, 77.18879, 1744.0], [15.53091, 73.76345, 1082.0], [26.29586, 74.73548, 2405.0], [18.697, 73.506, 1546.0], [18.73272, 72.86783, 1674.0], [26.98848, 75.58298, 1082.0], [15.50182, 73.81186, 3007.0], [18.65904, 72.87707, 842.0], [29.42102, 79.54799, 4381.0], [30.99192, 77.20999, 4351.0], [24.561, 73.637, 962.0], [29.42237, 79.54729, 4381.0], [28.49698, 77.13752, 4209.0], [22.516, 88.351, 6013.0], [28.575, 77.232, 4209.0], [18.52454, 73.87851, 4269.0], [32.00977, 77.31291, 4470.0], [25.59828, 85.17635, 4418.0], [28.4963, 77.15165, 4209.0], [26.61888, 70.70844, 4444.0], [28.49611, 77.15379, 3608.0], [13.06573, 77.4722, 4209.0], [12.03632, 92.99161, 5274.0], [15.59992, 73.77924, 4209.0], [9.46949, 76.38729, 698.0], [19.16242, 72.7834, 601.0], [15.56965, 73.75761, 661.0], [15.45279, 73.80111, 660.0], [15.615, 73.78, 598.0], [15.59117, 73.77654, 623.0], [15.5804, 73.75759, 771.0], [26.925, 75.801, 567.0], [18.67386, 73.39413, 624.0], [18.65748, 72.87744, 701.0], [32.28484, 77.17409, 505.0], [15.52543, 73.78704, 546.0], [15.52537, 73.84675, 754.0], [18.75593, 72.8881, 773.0], [18.75698, 73.39004, 579.0], [26
